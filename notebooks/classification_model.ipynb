# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm, tree
import xgboost
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import numpy as np

import sys
sys.path.insert(1, "../src/features")
import data_cleaning

# allows all columns to be displayed
pd.set_option('display.max_columns', None)

OFFER_DATA_DIR = "../data/offer_acceptance_offers.csv"
ORDER_DATA_DIR = "../data/offer_acceptance_orders.csv"

offers = pd.read_csv(OFFER_DATA_DIR, low_memory=False)[["CARRIER_ID", "REFERENCE_NUMBER", "CREATED_ON_HQ", "RATE_USD", "OFFER_TYPE", "LOAD_DELIVERED_FROM_OFFER"]]
orders = pd.read_csv(ORDER_DATA_DIR, low_memory=False)[["REFERENCE_NUMBER", "ORDER_DATETIME_PST", "PICKUP_DEADLINE_PST", "ORIGIN_3DIGIT_ZIP", "DESTINATION_3DIGIT_ZIP", "APPROXIMATE_DRIVING_ROUTE_MILEAGE", "PALLETIZED_LINEAR_FEET"]]

offers = data_cleaning.change_to_date(offers, ["CREATED_ON_HQ"])
orders = data_cleaning.change_to_date(orders, ["ORDER_DATETIME_PST", "PICKUP_DEADLINE_PST"])

orders = data_cleaning.parse_zipcode(orders)

orders = data_cleaning.parse_datetime(orders)

offers = data_cleaning.flatten_ref_num(offers)
orders = data_cleaning.flatten_ref_num(orders)

merged = data_cleaning.join_offers_orders(offers, orders, how="inner")

merged = data_cleaning.get_remaining_time(merged)

merged = data_cleaning.during_business_hours(merged)

pooled = data_cleaning.get_prorated_rate(merged)

merged = data_cleaning.impute_mileage(merged)

merged = data_cleaning.get_business_hours(merged)

# %%
 # filter for delivered offers
 merged = merged[merged["LOAD_DELIVERED_FROM_OFFER"]].reset_index(drop=True)

# drop unnecessary columns
 merged = merged.drop(["CARRIER_ID", "REFERENCE_NUMBER", "REMAINIG_TIME", "RATE_USD", "LOAD_DELIVERED_FROM_OFFER", "CREATED_ON_HQ", "ORIGIN_3DIGIT_ZIP", "DESTINATION_3DIGIT_ZIP"], axis=1)

# %%
df_y = df["POOLED"]
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MaxAbsScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

MAX_CATEGORIES = 30

df = merged.drop(["ORDER_DATETIME_PST", "PICKUP_DEADLINE_PST"], axis=1)
df["POOLED"] = df["OFFER_TYPE"] == "pool"
df = df.drop("OFFER_TYPE", axis=1)

df_X = df.drop("POOLED", axis=1)
df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(df_X, df_y, test_size=0.3, random_state=42)

num_feat = ["BUSINESS_HOURS", "APPROXIMATE_DRIVING_ROUTE_MILEAGE", "PALLETIZED_LINEAR_FEET", "BUSINESS_HOURS_ORDER_PICKUP"]
num_transformer = Pipeline(steps=[
    ('scaler', MaxAbsScaler()) # z-scale
])

cat_feat = ["ORIGIN_CITY", "DESTINATION_CITY", "ORDER_DAY", "ORDER_MONTH", "ORDER_HOUR", "PICKUP_DAY", "PICKUP_MONTH", "PICKUP_HOUR"]
cat_transformer = Pipeline(steps=[
    ("onehot", OneHotEncoder(max_categories = 30, handle_unknown="ignore"))     # output from Ordinal becomes input to OneHot
])

# preprocessing pipeline (put them together)
preproc = ColumnTransformer(
    transformers=[
        ("numerical", num_transformer, num_feat),
        ("categorization", cat_transformer, cat_feat)
    ])

pipeline = Pipeline(steps=[
    ('preprocessor', preproc), 
    ("xgb", xgboost.XGBClassifier())
])

param_grid = {
    'xgb__max_depth': [2, 3, 5, 7, 10],
    'xgb__n_estimators': [10, 100, 500],
    "xgb__reg_alpha": [0, 0.5, 1, 5],
    "xgb__reg_lambda": [0, 0.5, 1, 5]
}

from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(
    pipeline,
    param_grid = param_grid,
    scoring = 'accuracy',
    n_jobs = -1,
    cv = 5,
    verbose = 3,
)

grid.fit(df_X_train, df_y_train)
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.785 total time=   0.6s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.783 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.789 total time=   0.8s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.766 total time=   0.8s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.785 total time=   0.8s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.783 total time=   0.8s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.782 total time=   1.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.789 total time=   0.8s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.766 total time=   0.6s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.782 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.785 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.766 total time=   0.5s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.783 total time=   0.7s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.789 total time=   0.8s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.782 total time=   0.5s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.783 total time=   0.5s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.785 total time=   0.7s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.766 total time=   0.5s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.782 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.789 total time=   0.8s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.789 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.766 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.785 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.785 total time=   1.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.783 total time=   1.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.783 total time=   0.6s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.782 total time=   0.8s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.789 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.766 total time=   0.5s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.782 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.785 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.789 total time=   0.6s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.783 total time=   0.8s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.782 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.785 total time=   0.5s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.783 total time=   0.5s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.789 total time=   0.5s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.766 total time=   0.9s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.766 total time=   0.7s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.782 total time=   0.6s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.783 total time=   0.7s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.789 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.766 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.785 total time=   0.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.782 total time=   0.6s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.783 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.789 total time=   0.5s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.785 total time=   0.7s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.766 total time=   0.6s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.782 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.785 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.789 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.766 total time=   0.6s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.782 total time=   0.6s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.783 total time=   1.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.783 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.789 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.766 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.785 total time=   1.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.785 total time=   0.6s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.782 total time=   0.7s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.783 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.787 total time=   0.6s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.782 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.785 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.789 total time=   1.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.789 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.787 total time=   0.6s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.782 total time=   0.6s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.783 total time=   0.8s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.785 total time=   0.6s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.783 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.789 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.787 total time=   0.7s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.782 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.785 total time=   0.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.789 total time=   0.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.787 total time=   0.5s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.783 total time=   0.8s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.782 total time=   0.6s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.807 total time=   3.1s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.810 total time=   2.8s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.805 total time=   3.2s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.806 total time=   3.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.806 total time=   3.3s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.805 total time=   3.3s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.811 total time=   3.3s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.804 total time=   4.5s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.805 total time=   3.2s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.806 total time=   3.3s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.805 total time=   3.1s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.808 total time=   3.2s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.812 total time=   3.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.806 total time=   3.2s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.806 total time=   3.2s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.808 total time=   4.1s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.804 total time=   3.1s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.812 total time=   3.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.807 total time=   2.9s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.806 total time=   3.1s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.806 total time=   3.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.806 total time=   3.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.811 total time=   2.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.805 total time=   2.9s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.807 total time=   2.9s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.806 total time=   3.9s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.805 total time=   3.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.811 total time=   2.9s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.807 total time=   2.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.805 total time=   2.9s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.807 total time=   2.9s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.805 total time=   2.9s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.809 total time=   3.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.808 total time=   3.0s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.805 total time=   3.1s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.804 total time=   3.1s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.810 total time=   3.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.806 total time=   3.0s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.807 total time=   3.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.806 total time=   3.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.808 total time=   3.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.805 total time=   3.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.812 total time=   3.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.806 total time=   3.1s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.806 total time=   3.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.807 total time=   3.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.805 total time=   3.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.811 total time=   3.0s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.806 total time=   3.0s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.804 total time=   3.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.808 total time=   3.1s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.805 total time=   3.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.811 total time=   3.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.806 total time=   3.1s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.805 total time=   3.1s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.808 total time=   3.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.805 total time=   3.1s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.811 total time=   3.0s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.806 total time=   3.0s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.806 total time=   3.1s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.808 total time=   3.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.805 total time=   3.1s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.811 total time=   3.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.806 total time=   3.2s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.806 total time=   3.2s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.808 total time=   3.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.806 total time=   3.0s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.806 total time=   3.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.811 total time=   3.1s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.805 total time=   3.1s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.807 total time=   3.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.805 total time=   3.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.812 total time=   3.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.807 total time=   3.1s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.804 total time=   3.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.809 total time=   3.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.804 total time=   3.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.811 total time=   3.0s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.807 total time=   3.1s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.805 total time=   3.1s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.815 total time=  14.1s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.814 total time=  14.1s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.819 total time=  14.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.814 total time=  14.1s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.814 total time=  14.1s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.815 total time=  14.1s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.814 total time=  14.2s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.819 total time=  14.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.814 total time=  15.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.813 total time=  14.7s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.815 total time=  14.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.812 total time=  15.1s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.819 total time=  14.8s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.816 total time=  14.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.813 total time=  15.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.816 total time=  14.8s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.813 total time=  14.5s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.819 total time=  14.4s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.816 total time=  14.4s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.813 total time=  14.4s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.815 total time=  14.6s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.815 total time=  14.6s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.819 total time=  14.6s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.815 total time=  14.4s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.813 total time=  14.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.815 total time=  14.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.814 total time=  13.9s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.820 total time=  14.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.816 total time=  14.1s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.812 total time=  14.1s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.815 total time=  13.9s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.814 total time=  13.7s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.815 total time=  13.8s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.820 total time=  13.8s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.813 total time=  13.8s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.815 total time=  13.7s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.814 total time=  13.9s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.818 total time=  13.7s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.815 total time=  13.8s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.813 total time=  13.7s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.815 total time=  13.8s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.815 total time=  13.9s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.820 total time=  13.9s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.815 total time=  13.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.812 total time=  13.8s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.815 total time=  13.9s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.815 total time=  13.7s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.820 total time=  13.9s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.815 total time=  14.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.815 total time=  13.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.812 total time=  14.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.814 total time=  14.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.820 total time=  14.1s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.815 total time=  13.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.813 total time=  14.0s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.816 total time=  14.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.815 total time=  14.0s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.820 total time=  13.9s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.814 total time=  13.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.813 total time=  13.8s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.816 total time=  14.0s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.815 total time=  14.1s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.817 total time=  13.9s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.815 total time=  13.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.813 total time=  14.1s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.817 total time=  14.1s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.815 total time=  14.2s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.819 total time=  14.4s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.816 total time=  14.3s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.812 total time=  14.3s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.815 total time=  14.3s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.815 total time=  14.3s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.818 total time=  13.8s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.816 total time=  13.9s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.812 total time=  13.9s
# [CV 1/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.815 total time=  13.9s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.788 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.793 total time=   0.7s
# [CV 2/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.814 total time=  14.1s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.790 total time=   0.7s
# [CV 3/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.818 total time=  13.8s
# [CV 4/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.815 total time=  13.9s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.786 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.788 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.793 total time=   0.7s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.790 total time=   0.7s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.788 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.788 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.792 total time=   0.7s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.790 total time=   0.7s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.788 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.788 total time=   0.8s
# [CV 5/5] END xgb__max_depth=2, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.814 total time=  14.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.794 total time=   0.7s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.789 total time=   0.7s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.786 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.788 total time=   0.7s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.790 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.792 total time=   0.8s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.788 total time=   0.8s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.790 total time=   0.9s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.788 total time=   0.8s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.794 total time=   0.8s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.788 total time=   0.6s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.788 total time=   0.8s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.790 total time=   0.8s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.794 total time=   0.7s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.790 total time=   0.7s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.788 total time=   0.6s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.788 total time=   0.6s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.790 total time=   0.8s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.789 total time=   0.6s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.794 total time=   0.8s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.786 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.788 total time=   0.8s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.794 total time=   0.8s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.790 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.790 total time=   0.7s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.788 total time=   0.8s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.788 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.794 total time=   0.7s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.790 total time=   0.7s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.788 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.790 total time=   0.6s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.788 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.794 total time=   0.7s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.790 total time=   0.6s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.786 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.790 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.794 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.788 total time=   0.8s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.790 total time=   0.7s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.786 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.789 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.793 total time=   0.8s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.790 total time=   0.8s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.786 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.790 total time=   0.7s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.789 total time=   0.7s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.793 total time=   0.7s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.790 total time=   0.8s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.786 total time=   0.8s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.790 total time=   0.8s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.788 total time=   0.8s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.793 total time=   0.8s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.790 total time=   0.8s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.786 total time=   0.7s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.790 total time=   0.8s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.788 total time=   0.8s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.793 total time=   0.8s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.790 total time=   0.8s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=10, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.786 total time=   0.8s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.817 total time=   4.1s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.813 total time=   4.2s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.814 total time=   4.3s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.813 total time=   4.1s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.813 total time=   4.2s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.813 total time=   4.3s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.812 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.818 total time=   4.3s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.811 total time=   4.0s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.813 total time=   4.1s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.814 total time=   4.1s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.811 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.817 total time=   4.2s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.811 total time=   4.1s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.813 total time=   4.4s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.814 total time=   4.1s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.811 total time=   4.2s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.813 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.816 total time=   4.3s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.811 total time=   4.2s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.814 total time=   4.2s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.812 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.819 total time=   4.1s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.814 total time=   4.1s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.813 total time=   4.0s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.811 total time=   4.3s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.814 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.816 total time=   4.1s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.814 total time=   4.2s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.811 total time=   4.1s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.814 total time=   4.2s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.811 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.817 total time=   4.2s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.812 total time=   4.2s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.813 total time=   4.1s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.812 total time=   4.2s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.811 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.816 total time=   4.3s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.812 total time=   4.1s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.812 total time=   4.3s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.818 total time=   4.0s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.811 total time=   4.2s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.813 total time=   4.4s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.812 total time=   4.3s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.813 total time=   4.2s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.815 total time=   4.1s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.812 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.818 total time=   4.2s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.814 total time=   4.2s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.813 total time=   4.1s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.813 total time=   4.2s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.813 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.816 total time=   4.1s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.813 total time=   4.3s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.812 total time=   4.2s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.814 total time=   4.2s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.812 total time=   4.3s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.816 total time=   4.3s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.813 total time=   4.2s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.812 total time=   4.3s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.812 total time=   4.3s
# [CV 2/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.812 total time=   4.2s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.817 total time=   4.3s
# [CV 4/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.815 total time=   4.3s
# [CV 5/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.812 total time=   4.2s
# [CV 1/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.815 total time=   4.1s
# [CV 3/5] END xgb__max_depth=3, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.816 total time=   4.1s
# ...
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.821 total time=  15.9s
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.821 total time=  15.8s
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.828 total time=  15.6s
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.821 total time=  15.8s
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.819 total time=  15.6s
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.823 total time=  15.6s
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.822 total time=  14.7s
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.825 total time=  14.6s
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.822 total time=  14.6s
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.825 total time=  14.9s
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.822 total time=  15.5s
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.824 total time=  15.3s
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.825 total time=  15.3s
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.822 total time=  15.3s
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.819 total time=  16.6s
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.823 total time=  16.4s
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.824 total time=  16.5s
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.823 total time=  16.6s
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.821 total time=  16.5s
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.819 total time=  16.4s
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.823 total time=  16.4s
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.821 total time=  16.6s
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.823 total time=  15.8s
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.821 total time=  15.8s
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.821 total time=  15.9s
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.824 total time=  16.0s
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.824 total time=  15.9s
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.824 total time=  15.9s
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.821 total time=  15.9s
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=100, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.820 total time=  15.8s
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.822 total time= 1.2min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.819 total time= 1.2min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.820 total time= 1.2min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.819 total time= 1.2min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.820 total time= 1.2min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0;, score=0.818 total time= 1.2min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.821 total time= 1.2min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.819 total time= 1.2min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.818 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=0.5;, score=0.820 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.819 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.819 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.820 total time= 1.3min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.824 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.822 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=1;, score=0.820 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.821 total time= 1.2min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.825 total time= 1.2min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.823 total time= 1.2min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0, xgb__reg_lambda=5;, score=0.819 total time= 1.2min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.820 total time= 1.3min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.823 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.818 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.821 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0;, score=0.820 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.822 total time= 1.2min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.816 total time= 1.2min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.822 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.819 total time= 1.2min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.821 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=0.5;, score=0.819 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.820 total time= 1.3min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.821 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.822 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.821 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=1;, score=0.817 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.819 total time= 1.3min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.825 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.823 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=0.5, xgb__reg_lambda=5;, score=0.819 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.822 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.819 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.820 total time= 1.3min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.822 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0;, score=0.816 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.821 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.817 total time= 1.3min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.822 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.818 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=0.5;, score=0.819 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.820 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.821 total time= 1.3min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.823 total time= 1.3min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.821 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.821 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=1;, score=0.818 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.818 total time= 1.3min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.820 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.820 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=1, xgb__reg_lambda=5;, score=0.817 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.816 total time= 1.4min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.816 total time= 1.4min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.822 total time= 1.4min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.818 total time= 1.4min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0;, score=0.817 total time= 1.4min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.819 total time= 1.4min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.817 total time= 1.4min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.820 total time= 1.4min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.819 total time= 1.4min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=0.5;, score=0.814 total time= 1.4min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.819 total time= 1.4min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.817 total time= 1.4min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.819 total time= 1.4min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.820 total time= 1.4min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=1;, score=0.818 total time= 1.4min
# [CV 1/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.819 total time= 1.4min
# [CV 3/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.821 total time= 1.3min
# [CV 2/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.817 total time= 1.3min
# [CV 4/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.820 total time= 1.3min
# [CV 5/5] END xgb__max_depth=10, xgb__n_estimators=500, xgb__reg_alpha=5, xgb__reg_lambda=5;, score=0.817 total time= 1.3min
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('numerical',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           MaxAbsScaler())]),
#                                                                          ['BUSINESS_HOURS',
#                                                                           'APPROXIMATE_DRIVING_ROUTE_MILEAGE',
#                                                                           'PALLETIZED_LINEAR_FEET',
#                                                                           'BUSINESS_HOURS_ORDER_PICKUP']),
#                                                                         ('categorization',
#                                                                          Pipeline(steps=[('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         max_cate...
#                                                       max_depth=None,
#                                                       max_leaves=None,
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       n_estimators=100,
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None,
#                                                       predictor=None,
#                                                       random_state=None, ...))]),
#              n_jobs=-1,
#              param_grid={'xgb__max_depth': [2, 3, 5, 7, 10],
#                          'xgb__n_estimators': [10, 100, 500],
#                          'xgb__reg_alpha': [0, 0.5, 1, 5],
#                          'xgb__reg_lambda': [0, 0.5, 1, 5]},
#              scoring='accuracy', verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'xgb__max_depth': 10, 'xgb__n_estimators': 100, 'xgb__reg_alpha': 1, 'xgb__reg_lambda': 5}

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preproc), 
    ("xgb", xgboost.XGBClassifier(max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=5))
])

pipeline.fit(df_X_train, df_y_train)
y_preds = pipeline.predict(df_X_test)
acc = accuracy_score(y_preds, df_y_test)
acc
# Out:
# 0.8260964607221637

# %%
# classifiers = []

# xgb_model = xgboost.XGBClassifier()
# classifiers.append(xgb_model)

# # svm_model = svm.SVC()
# # classifiers.append(svm_model)

# # tree_model = tree.DecisionTreeClassifier()
# # classifiers.append(tree_model)

# # forest_model = RandomForestClassifier()
# # classifiers.append(forest_model)

# for clf in classifiers:
#     pl = Pipeline(steps=[('preprocessor', preproc), (str(clf), clf)])
    
#     pl.fit(df_X_train, df_y_train)
#     y_preds = pl.predict(df_X_test)
#     acc = accuracy_score(y_preds, df_y_test)
#     print("Accuracy of %s is %s"%(clf, acc))
# Out:
# Accuracy of XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...) is 0.8223803183561534

# %%
Change DateTime columns to unix timestamp
# Out:
#   Cell In[10], line 1
#     Change DateTime columns to unix timestamp
#            ^
# SyntaxError: invalid syntax
